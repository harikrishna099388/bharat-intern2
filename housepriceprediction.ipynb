# %% [markdown]
# <a href="https://colab.research.google.com/github/harikrishna099388/bharat-intern2/blob/main/housepriceprediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/House_Rent_Dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   object
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   object
#  5   Area Type          4746 non-null   object
#  6   Area Locality      4746 non-null   object
#  7   City               4746 non-null   object
#  8   Furnishing Status  4746 non-null   object
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   object
# dtypes: int64(4), object(8)
# memory usage: 445.1+ KB

# %%
df.isna().sum()
# Out:
# Posted On            0
# BHK                  0
# Rent                 0
# Size                 0
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Posted On            0
# BHK                  0
# Rent                 0
# Size                 0
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Posted On', 'BHK', 'Rent', 'Size', 'Floor', 'Area Type',
#        'Area Locality', 'City', 'Furnishing Status', 'Tenant Preferred',
#        'Bathroom', 'Point of Contact'],
#       dtype='object')

# %%
sns.histplot(df['Rent'],kde=True ,color = 'darkgreen' , edgecolor = 'black')
plt.xlabel('RENT  IN MILLIONS ')
plt.ylabel('COUNT')
# Out:
# Text(0, 0.5, 'COUNT')

# %%
sns.histplot(df['Area Type'],kde=True, color = 'maroon' , edgecolor = 'black')
plt.xlabel('Area Type')
plt.ylabel('COUNT')
# Out:
# Text(0, 0.5, 'COUNT')

# %%
df['BHK'].value_counts()
sns.barplot(df['BHK'].value_counts(),color = 'pink' , edgecolor = 'black')
plt.xlabel('NUMBER OF BHK')
plt.ylabel('NUMBER OF HOUSES')
# Out:
# Text(0, 0.5, 'NUMBER OF HOUSES')

# %%
sns.barplot(df['Size'].value_counts() , color = 'pink' , edgecolor = 'black')
plt.xlabel('NUMBER OF Size')
plt.ylabel('NUMBER OF HOUSES')
# Out:
# Text(0, 0.5, 'NUMBER OF HOUSES')

# %%
sns.barplot(df['Floor'].value_counts(), color = 'pink' , edgecolor = 'black' )
plt.xlabel('NUMBER OF Floor')
plt.ylabel('NUMBER OF HOUSES')
# Out:
# Text(0, 0.5, 'NUMBER OF HOUSES')

# %%
sns.barplot(df['Point of Contact'].value_counts(), color = 'pink' , edgecolor = 'black' )
plt.xlabel('Point of Contact')
plt.ylabel('NUMBER OF HOUSES')
# Out:
# Text(0, 0.5, 'NUMBER OF HOUSES')

# %%
sns.barplot(df['Bathroom'].value_counts(), color = 'pink' , edgecolor = 'black' )
plt.xlabel('Bathroom')
plt.ylabel('NUMBER OF HOUSES')
# Out:
# Text(0, 0.5, 'NUMBER OF HOUSES')

# %%
sns.barplot(df['Posted On'].value_counts(), color = 'pink' , edgecolor = 'black' )
plt.xlabel('Posted On')
plt.ylabel('NUMBER OF HOUSES')
# Out:
# Text(0, 0.5, 'NUMBER OF HOUSES')

# %%
sns.barplot(df['Area Locality'].value_counts(), color = 'pink' , edgecolor = 'black' )
plt.xlabel('Area Locality')
plt.ylabel('NUMBER OF HOUSES')
# Out:
# Text(0, 0.5, 'NUMBER OF HOUSES')

# %%
sns.barplot(df['City'].value_counts(), color = 'pink' , edgecolor = 'black' )
plt.xlabel('City')
plt.ylabel('NUMBER OF HOUSES')
# Out:
# Text(0, 0.5, 'NUMBER OF HOUSES')

# %%
sns.barplot(df['Furnishing Status'].value_counts(), color = 'pink' , edgecolor = 'black' )
plt.xlabel('Furnishing Status')
plt.ylabel('NUMBER OF HOUSES')
# Out:
# Text(0, 0.5, 'NUMBER OF HOUSES')

# %%
sns.barplot(df['Tenant Preferred'].value_counts(), color = 'pink' , edgecolor = 'black' )
plt.xlabel('Tenant Preferred')
plt.ylabel('NUMBER OF HOUSES')
# Out:
# Text(0, 0.5, 'NUMBER OF HOUSES')

# %%
df.head()
# Out:
#     Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4  2022-05-09    2   7500   850       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner
# ...
